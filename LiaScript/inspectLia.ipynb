# %%
import pandas as pd

# %%
path = "/mnt/9cd5c6a1-07f3-4580-be34-8d8dd9d6fe6d/Connected_Lecturers/LiaScript/raw/LiaScript_files.p"

df = pd.read_pickle(path)

# %%
df.columns
# Out:
# Index(['repo_name', 'repo_user', 'repo_url', 'file_name', 'file_download_url',
#        'file_html_url', 'file_content'],
#       dtype='object')

# %%
df.tail(3)
# Out:
#                                           repo_name repo_user  \
# 5125  C-background-development-interview-experience   hujiese
# 5126  C-background-development-interview-experience   hujiese
# 5127  C-background-development-interview-experience   hujiese
#
#                                                repo_url  file_name  \
# 5125  https://github.com/hujiese/C-background-develo...  README.md
# 5126  https://github.com/hujiese/C-background-develo...  README.md
# 5127  https://github.com/hujiese/C-background-develo...  README.md
#
#                                       file_download_url  \
# 5125  https://raw.githubusercontent.com/hujiese/C-ba...
# 5126  https://raw.githubusercontent.com/hujiese/C-ba...
# 5127  https://raw.githubusercontent.com/hujiese/C-ba...
#
#                                           file_html_url  \
# 5125  https://github.com/hujiese/C-background-develo...
# 5126  https://github.com/hujiese/C-background-develo...
# ...

# %%
df[df.repo_user!="hujiese"]
# Out:
#                   repo_name      repo_user  \
# 0     LiaTranscriptLiveEdit        Buhlean
# 1     LiaTranscriptLiveEdit        Buhlean
# 2        material-liascript        vibbits
# 3        material-liascript        vibbits
# 4        material-liascript        vibbits
# ...                     ...            ...
# 5042     hackernews-2024-zh      OpenDocCN
# 5043     hackernews-2024-zh      OpenDocCN
# 5044   freecodecamp-blog-zh       apachecn
# 5045   freecodecamp-blog-zh      OpenDocCN
# 5046      evento-interacoes  AndreaInfUFSM
#
#                                                repo_url  \
# 0      https://github.com/Buhlean/LiaTranscriptLiveEdit
# 1      https://github.com/Buhlean/LiaTranscriptLiveEdit
# 2         https://github.com/vibbits/material-liascript
# 3         https://github.com/vibbits/material-liascript
# 4         https://github.com/vibbits/material-liascript
# ...                                                 ...
# ...
