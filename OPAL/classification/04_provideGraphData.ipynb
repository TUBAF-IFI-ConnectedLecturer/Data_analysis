# %%
from pathlib import Path
import pandas as pd

# %%
import sys
sys.path.append('../../src')
from DataHandler import DataHandler

# %% [markdown]
# # Erzeugung der Graphdaten
#
# ## Knoten

# %%
dataHandler = DataHandler("../config.yaml")
df_opalmeta = dataHandler.load_data("files.df_opalmeta")
df_opalmeta.head(3)
# Out:
# /media/sz/Data/Connected_Lecturers/Opal_transfer/raw/OPAL_files_attrib.p
#      opal:filename                                 opal:oer_permalink  \
# 0  SC_Hardware.png  https://bildungsportal.sachsen.de/opal/oer/6TI...
# 1        beleg.pdf  https://bildungsportal.sachsen.de/opal/oer/8I6...
# 2  Bereich III.pdf  https://bildungsportal.sachsen.de/opal/oer/8ZI...
#
#            opal:license       opal:author                      opal:title  \
# 0        CC BY 4.0 Int.  Daniela Dobeleit  Hardware zum Styroporschneiden
# 1     CC BY-SA 4.0 Int.
# 2  CC BY-NC-ND 4.0 Int.
#
#   opal:comment opal:language opal:publicationMonth opal:publicationYear  \
# 0
# 1
# 2
#
#                                   opal:revisedAuthor       pipe:ID  \
# 0  [Vorname='Daniela' Familienname='Dobeleit' Tit...  6TIlFGfTxXkw
# 1                                                     8I6sM5zapD60
# 2                                                     8ZICOHBmAHyQ
#
#   pipe:file_type
# 0            png
# 1            pdf
# 2            pdf

# %%
df_filesmeta = dataHandler.load_data("files.df_filesmeta")
df_filesmeta.head(3)
# Out:
# /media/sz/Data/Connected_Lecturers/Opal_transfer/raw/OPAL_files_meta.p
#         pipe:ID pipe:file_type file:author file:keywords file:subject  \
# 0  8I6sM5zapD60            pdf
# 1  8ZICOHBmAHyQ            pdf
# 2  8Lfz8SAKa6k0            pdf
#
#   file:title              file:created             file:modified  \
# 0            2019-01-11 17:12:31+00:00 2019-01-11 17:12:31+00:00
# 1            2019-10-25 12:05:54+00:00 2019-10-25 12:05:54+00:00
# 2            2024-12-20 07:48:12+00:00                       NaT
#
#   file:language file:revisedAuthor
# 0           NaN
# 1           NaN
# 2           NaN

# %%
df_aimeta = dataHandler.load_data("files.df_aimeta")
df_aimeta.head(3)
# Out:
# /media/sz/Data/Connected_Lecturers/Opal_transfer/raw/OPAL_ai_meta.p
#         pipe:ID pipe:file_type                      ai:author  \
# 0  8I6sM5zapD60            pdf  Stephan Gerhold, Marcel Beyer
# 1  8ZICOHBmAHyQ            pdf                  Keine Angabe.
# 2  8Lfz8SAKa6k0            pdf                  Robert Ringel
#
#                                     ai:revisedAuthor ai:affilation  \
# 0  [Vorname='Stephan' Familienname='Gerhold' Tite...
# 1                                                 []
# 2  [Vorname='Robert' Familienname='Ringel' Titel='']
#
#                                             ai:title        ai:type  \
# 0                            Übung 3 Photogrammetrie  Aufgabenblatt
# 1                       3.1 Grundlagen der Tragwerke         Skript
# 2  Gedanken und Notizen zu unserem Mini-KI-Worksh...      Protokoll
#
#                                      ai:keywords_ext  \
# 0  Photogrammetrie, digitale Entzerrung, Resampli...
# 1  Tragwerke, Lagerreaktionen, Gleichgewichtsbedi...
# 2  Künstliche Intelligenz, Automatisierung, Indus...
#
#                                      ai:keywords_gen  \
# 0  Photogrammetrie, digitale Entzerrung, Resampli...
# 1  Tragwerke, Lagerreaktionen, Gleichgewichtsbedi...
# 2  Künstliche Intelligenz, Automatisierung, Indus...
#
#                                      ai:keywords_dnb  ...  \
# 0  Photogrammetrie, Bildverarbeitung, Digitale En...  ...
# 1  Statik, Tragwerke, Mechanik, Festigkeitslehre,...  ...
# 2  Künstliche Intelligenz, Automatisierung, Indus...  ...
#
#                                  ai:keywords_dnb_ids  \
# 0           [0, 1, 2, 9, 11, 12, 14, 15, 16, 17, 18]
# 1     [34, 35, 36, 37, 38, 19, 20, 21, 22, 9079, 24]
# 2  [39, 40, 49, 52, 55, 54, 3191, 56, 3193, 58, 5...
#
#                 ai:keywords_ext_ids_valid ai:keywords_ext_valid_ratio  \
# 0                           [0, 1, 4, 14]                    0.333333
# 1                        [19, 24, 27, 28]                    0.363636
# 2  [39, 40, 41, 42, 43, 45, 46, 47, 3191]                    0.750000
#
#                            ai:keywords_dnb_ids_valid  \
# 0                             [0, 1, 11, 12, 14, 16]
# 1                       [34, 35, 36, 37, 38, 19, 24]
# 2  [39, 40, 49, 52, 55, 54, 3191, 56, 3193, 58, 5...
#
#   ai:keywords_dnb_valid_ratio           ai:keywords_gen_ids_valid  \
# 0                    0.545455               [0, 1, 4, 11, 12, 14]
# 1                    0.636364                    [33, 19, 27, 30]
# 2                    1.000000  [39, 40, 43, 45, 47, 49, 52, 3191]
#
#   ai:keywords_gen_valid_ratio  \
# 0                    0.545455
# 1                    0.363636
# 2                    0.666667
#
#                                    all_ddc_valid_ids ddc_valid_count  \
# 0  [0, 1, 4, 14, 0, 1, 11, 12, 14, 16, 0, 1, 4, 1...              16
# 1  [19, 24, 27, 28, 34, 35, 36, 37, 38, 19, 24, 3...              15
# 2  [39, 40, 41, 42, 43, 45, 46, 47, 3191, 39, 40,...              29
#
#                                   valid_ddc_keywords
# 0  [Photogrammetrie, digitale Entzerrung, Paralle...
# 1  [Tragwerke, Festigkeitslehre, Freiheitsgrade, ...
# 2  [Künstliche Intelligenz, Automatisierung, Indu...
#
# [3 rows x 25 columns]

# %% [markdown]
# ### Let's start with authors names ...

# %%
def extract_first_three_lastnames(name_list):
    """
    Extrahiert die ersten drei Nachnamen aus der ai:revisedAuthor Spalte.
    
    Args:
        name_list (list): Liste von Name-Objekten aus der ai:revisedAuthor Spalte
        
    Returns:
        str: String mit den ersten drei Nachnamen, getrennt durch Kommata
    """
    # Prüfe ob die Liste leer oder None ist
    if not name_list or len(name_list) == 0:
        return ""
    
    # Extrahiere die Familiennamen aus den ersten drei Name-Objekten
    lastnames = []
    for i, name_obj in enumerate(name_list[:3]):  # Nur die ersten drei
        if hasattr(name_obj, 'Familienname'):
            lastname = name_obj.Familienname
            if len(lastname) > 1:
                if lastname and lastname.strip():  # Prüfe auf leere Strings
                    lastnames.append(lastname.strip())
    
    # Verbinde die Nachnamen mit Kommata zu einem String
    return ", ".join(lastnames)

# %%
df_aimeta['ai:revisedAuthorstr'] = df_aimeta['ai:revisedAuthor'].apply(extract_first_three_lastnames)
df_filesmeta['file:revisedAuthorstr'] = df_filesmeta['file:revisedAuthor'].apply(extract_first_three_lastnames)
df_opalmeta['opal:revisedAuthorstr'] = df_opalmeta['opal:revisedAuthor'].apply(extract_first_three_lastnames)

# %%
# merge all three dataframe by pipe:ID. Just keep 'ai:revisedAuthorstr', 'file:revisedAuthorstr', 'opal:revisedAuthorstr'
df_nodes = df_aimeta[['pipe:ID', 'ai:revisedAuthorstr', 'ai:affilation',
                      'ai:title', 'pipe:file_type', 'ai:type', 'ai:keywords_dnb',
                      'ai:summary']].merge(
    df_filesmeta[['pipe:ID', 'file:revisedAuthorstr']],
    on='pipe:ID',
    how='left'
).merge(
    df_opalmeta[['pipe:ID', 'opal:revisedAuthorstr','opal:oer_permalink']],
    on='pipe:ID',
    how='left'
)

# %%
#  replace all NaN strings with empty strings
df_nodes = df_nodes.fillna('')

df_nodes['Authors'] = "nicht bekannt"

# Wenn nur eine Spalte Werte hat, verwende diese (aber nur wenn sie nicht leer ist!)
df_nodes.loc[(df_nodes['ai:revisedAuthorstr'] == '') & 
                      (df_nodes['file:revisedAuthorstr'] == '') &
                      (df_nodes['opal:revisedAuthorstr'] != ''), 'Authors'] = df_nodes['opal:revisedAuthorstr']

df_nodes.loc[(df_nodes['ai:revisedAuthorstr'] == '') & 
                      (df_nodes['opal:revisedAuthorstr'] == '') &
                      (df_nodes['file:revisedAuthorstr'] != ''), 'Authors'] = df_nodes['file:revisedAuthorstr']

df_nodes.loc[(df_nodes['file:revisedAuthorstr'] == '') & 
                      (df_nodes['opal:revisedAuthorstr'] == '') &
                      (df_nodes['ai:revisedAuthorstr'] != ''), 'Authors'] = df_nodes['ai:revisedAuthorstr']

# Wenn zwei Spalten Werte haben und gleich sind
df_nodes.loc[(df_nodes['ai:revisedAuthorstr'] != '') & 
                      (df_nodes['file:revisedAuthorstr'] != '') &
                      (df_nodes['ai:revisedAuthorstr'] == df_nodes['file:revisedAuthorstr']), 'Authors'] = df_nodes['ai:revisedAuthorstr']

df_nodes.loc[(df_nodes['ai:revisedAuthorstr'] != '') & 
                      (df_nodes['opal:revisedAuthorstr'] != '') &
                      (df_nodes['ai:revisedAuthorstr'] == df_nodes['opal:revisedAuthorstr']), 'Authors'] = df_nodes['ai:revisedAuthorstr']

df_nodes.loc[(df_nodes['file:revisedAuthorstr'] != '') & 
                      (df_nodes['opal:revisedAuthorstr'] != '') &
                      (df_nodes['file:revisedAuthorstr'] == df_nodes['opal:revisedAuthorstr']), 'Authors'] = df_nodes['file:revisedAuthorstr']   

# Wenn zwei oder mehr Spalten unterschiedliche Werte haben, bevorzuge ai:revisedAuthorstr
df_nodes.loc[(df_nodes['ai:revisedAuthorstr'] != '') & 
                      (df_nodes['file:revisedAuthorstr'] != '') &
                      (df_nodes['ai:revisedAuthorstr'] != df_nodes['file:revisedAuthorstr']), 'Authors'] = df_nodes['ai:revisedAuthorstr']

df_nodes.loc[(df_nodes['ai:revisedAuthorstr'] != '') & 
                      (df_nodes['opal:revisedAuthorstr'] != '') &
                      (df_nodes['ai:revisedAuthorstr'] != df_nodes['opal:revisedAuthorstr']), 'Authors'] = df_nodes['ai:revisedAuthorstr']

# Aber wenn ai leer ist und file/opal unterschiedlich sind, bevorzuge file
df_nodes.loc[(df_nodes['ai:revisedAuthorstr'] == '') & 
                      (df_nodes['file:revisedAuthorstr'] != '') & 
                      (df_nodes['opal:revisedAuthorstr'] != '') &
                      (df_nodes['file:revisedAuthorstr'] != df_nodes['opal:revisedAuthorstr']), 'Authors'] = df_nodes['file:revisedAuthorstr']

# %%
def make_link(url, link):
    return f'<a href="{url}">{link}</a><br>'

df_nodes['Link'] = df_nodes.apply(lambda x: make_link(x['opal:oer_permalink'], "Link"), axis=1)

# %%
df_nodes.columns
# Out:
# Index(['pipe:ID', 'ai:revisedAuthorstr', 'ai:affilation', 'ai:title',
#        'pipe:file_type', 'ai:type', 'ai:keywords_dnb', 'ai:summary',
#        'file:revisedAuthorstr', 'opal:revisedAuthorstr', 'opal:oer_permalink',
#        'Authors', 'Link'],
#       dtype='object')

# %%
df_nodes.drop(columns=['ai:revisedAuthorstr', 
                       'file:revisedAuthorstr',
                       'opal:revisedAuthorstr',
                       ], inplace=True)


df_nodes.rename(columns={
    'pipe:ID': 'ID',
    'ai:affilation': 'Affiliation',
    'ai:title': 'Title',
    'pipe:file_type': 'File Type',
    'ai:type': 'Type',
    'ai:keywords_dnb': 'Keywords DNB',
    'opal:oer_permalink': 'permalink',
    'ai:summary': 'Summary',
}, inplace=True)

# %%
df_nodes.head(3)
# Out:
#              ID Affiliation  \
# 0  8I6sM5zapD60
# 1  8ZICOHBmAHyQ
# 2  8Lfz8SAKa6k0
#
#                                                Title File Type           Type  \
# 0                            Übung 3 Photogrammetrie       pdf  Aufgabenblatt
# 1                       3.1 Grundlagen der Tragwerke       pdf         Skript
# 2  Gedanken und Notizen zu unserem Mini-KI-Worksh...       pdf      Protokoll
#
#                                         Keywords DNB Summary  \
# 0  Photogrammetrie, Bildverarbeitung, Digitale En...
# 1  Statik, Tragwerke, Mechanik, Festigkeitslehre,...
# 2  Künstliche Intelligenz, Automatisierung, Indus...
#
#                                            permalink         Authors  \
# 0  https://bildungsportal.sachsen.de/opal/oer/8I6...  Gerhold, Beyer
# 1  https://bildungsportal.sachsen.de/opal/oer/8ZI...   nicht bekannt
# 2  https://bildungsportal.sachsen.de/opal/oer/8Lf...          Ringel
#
#                                                 Link
# 0  <a href="https://bildungsportal.sachsen.de/opa...
# 1  <a href="https://bildungsportal.sachsen.de/opa...
# 2  <a href="https://bildungsportal.sachsen.de/opa...

# %%
processed_data_folder = dataHandler.config_manager.get("folder_structure.processed_data_folder")
df_nodes[['ID', 'Affiliation', 'Title', 'File Type', 
          'Type', 'Keywords DNB', 'Link']].to_html(Path(processed_data_folder)/'nodes.html', render_links=True, escape=False, index=False)

# %%
df_nodes[['ID', 'Affiliation', 'Title', 'Summary', 'File Type',
           'Type', 'Keywords DNB', 'permalink']].to_json(Path(processed_data_folder) / "nodes.json", orient='records', force_ascii=False, indent=4)

# %% [markdown]
# ## Kanten

# %%
df_similarity = dataHandler.load_data("files.df_similarity")
df_similarity.head(3)
# Out:
# /media/sz/Data/Connected_Lecturers/Opal_transfer/processed/similarity_all_metrics.p
#           file1         file2                          Pair  similarity_ai  \
# 0  8I6sM5zapD60  8ZICOHBmAHyQ  (8I6sM5zapD60, 8ZICOHBmAHyQ)       0.381628
# 1  8I6sM5zapD60  8Lfz8SAKa6k0  (8I6sM5zapD60, 8Lfz8SAKa6k0)       0.141063
# 2  3ztCv-WpxJ4U  8I6sM5zapD60  (3ztCv-WpxJ4U, 8I6sM5zapD60)       0.266481
#
#    similarity_minhash_text  similarity_cosine  similarity_jaccard  \
# 0                      0.0           0.000000            0.000000
# 1                      0.0           0.437595            0.111111
# 2                      0.0           0.000000            0.000000
#
#    similarity_weighted_jaccard  similarity_tf_idf_cosine  similarity_overlap  \
# 0                       0.0000                  0.000000                0.00
# 1                       0.0625                  0.203601                0.25
# 2                       0.0000                  0.000000                0.00
#
#    similarity_dice  similarity_hierarchical
# 0              0.0                 0.133333
# 1              0.2                 0.151923
# 2              0.0                 0.028571

# %%
df_similarity.rename(columns={
    'file1': 'ID_A',
    'file2': 'ID_B',
    'similarity_ai': 'similarity',
}, inplace=True)

# %%
df_similarity = df_similarity[['ID_A', 'ID_B', 'similarity', ]]
df_similarity.head(3)
# Out:
#            ID_A          ID_B  similarity
# 0  8I6sM5zapD60  8ZICOHBmAHyQ    0.381628
# 1  8I6sM5zapD60  8Lfz8SAKa6k0    0.141063
# 2  3ztCv-WpxJ4U  8I6sM5zapD60    0.266481

# %%
# plot histogram of similarity
import matplotlib.pyplot as plt     
plt.figure(figsize=(10, 6))
plt.hist(df_similarity['similarity'], bins=50, color='blue', alpha=0.7)
plt.title('Histogram of Similarity')
plt.xlabel('Similarity')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
df_similarity = df_similarity[df_similarity['similarity'] > 0.75]
df_similarity
# Out:
#                    ID_A           ID_B  similarity
# 5235       3U5yNPASal48   8ZICOHBmAHyQ    0.785076
# 5239       8ZICOHBmAHyQ   8_DX9YKSbaWM    0.754103
# 5315       3IFcAFKeH-Zk   8ZICOHBmAHyQ    0.764661
# 14428      31T9CSmRS8IA   3ztCv-WpxJ4U    0.778182
# 14519      3ztCv-WpxJ4U   5JM-uwBxPKKU    0.788543
# ...                 ...            ...         ...
# 10339616  12IVVtroo82Uk  12mhRsKRcGP7w    0.869402
# 10339625   6N1ggFcTCAMM   6_FRRNUh8FaM    0.955884
# 10339730   96KYDYTG2uu0   9GYE_fdB8Ec8    0.941997
# 10339785  10MPMUvFFT_H0   3m2mmmncS4-4    0.841018
# 10339825  127HM_Da6VkYA  12ssH8ETGoeDU    0.788730
#
# [50628 rows x 3 columns]

# %%
df_similarity.to_json(Path(processed_data_folder) / "edges.json", orient='records', force_ascii=False, indent=4)
